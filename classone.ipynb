# %%
from pyspark.sql import SparkSession
spark=SparkSession.builder.appName('Create_DataFrame').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://7cc31da2708f:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Create_DataFrame</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df = spark.read.csv('F1_Complete_Dataset/races.csv')

# %%
df.show()
# Out:
# +------+----+-----+---------+--------------------+----------+--------+--------------------+--------+--------+--------+--------+--------+--------+----------+----------+-----------+-----------+
# |   _c0| _c1|  _c2|      _c3|                 _c4|       _c5|     _c6|                 _c7|     _c8|     _c9|    _c10|    _c11|    _c12|    _c13|      _c14|      _c15|       _c16|       _c17|
# +------+----+-----+---------+--------------------+----------+--------+--------------------+--------+--------+--------+--------+--------+--------+----------+----------+-----------+-----------+
# |raceId|year|round|circuitId|                name|      date|    time|                 url|fp1_date|fp1_time|fp2_date|fp2_time|fp3_date|fp3_time|quali_date|quali_time|sprint_date|sprint_time|
# |     1|2009|    1|        1|Australian Grand ...|2009-03-29|06:00:00|http://en.wikiped...|      \N|      \N|      \N|      \N|      \N|      \N|        \N|        \N|         \N|         \N|
# ...

# %%
df.show(n = 10, truncate = True)
# Out:
# +------+----+-----+---------+--------------------+----------+--------+--------------------+--------+--------+--------+--------+--------+--------+----------+----------+-----------+-----------+
# |   _c0| _c1|  _c2|      _c3|                 _c4|       _c5|     _c6|                 _c7|     _c8|     _c9|    _c10|    _c11|    _c12|    _c13|      _c14|      _c15|       _c16|       _c17|
# +------+----+-----+---------+--------------------+----------+--------+--------------------+--------+--------+--------+--------+--------+--------+----------+----------+-----------+-----------+
# |raceId|year|round|circuitId|                name|      date|    time|                 url|fp1_date|fp1_time|fp2_date|fp2_time|fp3_date|fp3_time|quali_date|quali_time|sprint_date|sprint_time|
# |     1|2009|    1|        1|Australian Grand ...|2009-03-29|06:00:00|http://en.wikiped...|      \N|      \N|      \N|      \N|      \N|      \N|        \N|        \N|         \N|         \N|
# ...

# %%
df.show(n = 10, truncate = False)
# Out:
# +------+----+-----+---------+---------------------+----------+--------+-------------------------------------------------------+--------+--------+--------+--------+--------+--------+----------+----------+-----------+-----------+
# |_c0   |_c1 |_c2  |_c3      |_c4                  |_c5       |_c6     |_c7                                                    |_c8     |_c9     |_c10    |_c11    |_c12    |_c13    |_c14      |_c15      |_c16       |_c17       |
# +------+----+-----+---------+---------------------+----------+--------+-------------------------------------------------------+--------+--------+--------+--------+--------+--------+----------+----------+-----------+-----------+
# |raceId|year|round|circuitId|name                 |date      |time    |url                                                    |fp1_date|fp1_time|fp2_date|fp2_time|fp3_date|fp3_time|quali_date|quali_time|sprint_date|sprint_time|
# ...

# %%
df = spark.read.option('header', 'true').csv('F1_Complete_Dataset/races.csv')
df.show(n = 10, truncate = True)
# Out:
# +------+----+-----+---------+--------------------+----------+--------+--------------------+--------+--------+--------+--------+--------+--------+----------+----------+-----------+-----------+
# |raceId|year|round|circuitId|                name|      date|    time|                 url|fp1_date|fp1_time|fp2_date|fp2_time|fp3_date|fp3_time|quali_date|quali_time|sprint_date|sprint_time|
# +------+----+-----+---------+--------------------+----------+--------+--------------------+--------+--------+--------+--------+--------+--------+----------+----------+-----------+-----------+
# |     1|2009|    1|        1|Australian Grand ...|2009-03-29|06:00:00|http://en.wikiped...|      \N|      \N|      \N|      \N|      \N|      \N|        \N|        \N|         \N|         \N|
# |     2|2009|    2|        2|Malaysian Grand Prix|2009-04-05|09:00:00|http://en.wikiped...|      \N|      \N|      \N|      \N|      \N|      \N|        \N|        \N|         \N|         \N|
# ...

# %%
df.printSchema()
# Out:
# root
#  |-- raceId: string (nullable = true)
#  |-- year: string (nullable = true)
#  |-- round: string (nullable = true)
#  |-- circuitId: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- date: string (nullable = true)
#  |-- time: string (nullable = true)
#  |-- url: string (nullable = true)
#  |-- fp1_date: string (nullable = true)
#  |-- fp1_time: string (nullable = true)
#  |-- fp2_date: string (nullable = true)
#  |-- fp2_time: string (nullable = true)
#  |-- fp3_date: string (nullable = true)
#  |-- fp3_time: string (nullable = true)
#  |-- quali_date: string (nullable = true)
#  |-- quali_time: string (nullable = true)
#  |-- sprint_date: string (nullable = true)
#  |-- sprint_time: string (nullable = true)

# %%
df = spark.read.option('header', 'true').option('inferschema','true').csv('F1_Complete_Dataset/races.csv')
df.show(n = 5)
# Out:
# +------+----+-----+---------+--------------------+----------+--------+--------------------+--------+--------+--------+--------+--------+--------+----------+----------+-----------+-----------+
# |raceId|year|round|circuitId|                name|      date|    time|                 url|fp1_date|fp1_time|fp2_date|fp2_time|fp3_date|fp3_time|quali_date|quali_time|sprint_date|sprint_time|
# +------+----+-----+---------+--------------------+----------+--------+--------------------+--------+--------+--------+--------+--------+--------+----------+----------+-----------+-----------+
# |     1|2009|    1|        1|Australian Grand ...|2009-03-29|06:00:00|http://en.wikiped...|      \N|      \N|      \N|      \N|      \N|      \N|        \N|        \N|         \N|         \N|
# |     2|2009|    2|        2|Malaysian Grand Prix|2009-04-05|09:00:00|http://en.wikiped...|      \N|      \N|      \N|      \N|      \N|      \N|        \N|        \N|         \N|         \N|
# ...

# %%
df.printSchema()
# Out:
# root
#  |-- raceId: integer (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- round: integer (nullable = true)
#  |-- circuitId: integer (nullable = true)
#  |-- name: string (nullable = true)
#  |-- date: date (nullable = true)
#  |-- time: string (nullable = true)
#  |-- url: string (nullable = true)
#  |-- fp1_date: string (nullable = true)
#  |-- fp1_time: string (nullable = true)
#  |-- fp2_date: string (nullable = true)
#  |-- fp2_time: string (nullable = true)
#  |-- fp3_date: string (nullable = true)
#  |-- fp3_time: string (nullable = true)
#  |-- quali_date: string (nullable = true)
#  |-- quali_time: string (nullable = true)
#  |-- sprint_date: string (nullable = true)
#  |-- sprint_time: string (nullable = true)

# %%
df =  spark.read.options(header = 'true',inferSchema = 'true').csv('F1_Complete_Dataset/races.csv')
df.show(10)
# Out:
# +------+----+-----+---------+--------------------+----------+--------+--------------------+--------+--------+--------+--------+--------+--------+----------+----------+-----------+-----------+
# |raceId|year|round|circuitId|                name|      date|    time|                 url|fp1_date|fp1_time|fp2_date|fp2_time|fp3_date|fp3_time|quali_date|quali_time|sprint_date|sprint_time|
# +------+----+-----+---------+--------------------+----------+--------+--------------------+--------+--------+--------+--------+--------+--------+----------+----------+-----------+-----------+
# |     1|2009|    1|        1|Australian Grand ...|2009-03-29|06:00:00|http://en.wikiped...|      \N|      \N|      \N|      \N|      \N|      \N|        \N|        \N|         \N|         \N|
# |     2|2009|    2|        2|Malaysian Grand Prix|2009-04-05|09:00:00|http://en.wikiped...|      \N|      \N|      \N|      \N|      \N|      \N|        \N|        \N|         \N|         \N|
# ...

# %%
df.describe().show()
# Out:
# +-------+-----------------+------------------+-----------------+------------------+--------------------+--------+--------------------+----------+--------+----------+--------+----------+--------+----------+----------+-----------+-----------+
# |summary|           raceId|              year|            round|         circuitId|                name|    time|                 url|  fp1_date|fp1_time|  fp2_date|fp2_time|  fp3_date|fp3_time|quali_date|quali_time|sprint_date|sprint_time|
# +-------+-----------------+------------------+-----------------+------------------+--------------------+--------+--------------------+----------+--------+----------+--------+----------+--------+----------+----------+-----------+-----------+
# |  count|             1125|              1125|             1125|              1125|                1125|    1125|                1125|      1125|    1125|      1125|    1125|      1125|    1125|      1125|      1125|       1125|       1125|
# ...

# %%
df.select('year','round','name').show(5)
# Out:
# +----+-----+--------------------+
# |year|round|                name|
# +----+-----+--------------------+
# |2009|    1|Australian Grand ...|
# |2009|    2|Malaysian Grand Prix|
# |2009|    3|  Chinese Grand Prix|
# |2009|    4|  Bahrain Grand Prix|
# |2009|    5|  Spanish Grand Prix|
# +----+-----+--------------------+
# only showing top 5 rows

# %%
df.select(df.year, df.name).show(5)
# Out:
# +----+--------------------+
# |year|                name|
# +----+--------------------+
# |2009|Australian Grand ...|
# |2009|Malaysian Grand Prix|
# |2009|  Chinese Grand Prix|
# |2009|  Bahrain Grand Prix|
# |2009|  Spanish Grand Prix|
# +----+--------------------+
# only showing top 5 rows

# %%
from pyspark.sql.functions import col

df.select(col("year"), col("name")).show(10)
# Out:
# +----+--------------------+
# |year|                name|
# +----+--------------------+
# |2009|Australian Grand ...|
# |2009|Malaysian Grand Prix|
# |2009|  Chinese Grand Prix|
# |2009|  Bahrain Grand Prix|
# |2009|  Spanish Grand Prix|
# |2009|   Monaco Grand Prix|
# |2009|  Turkish Grand Prix|
# |2009|  British Grand Prix|
# |2009|   German Grand Prix|
# |2009|Hungarian Grand Prix|
# +----+--------------------+
# only showing top 10 rows

# %%
df.select(df["year"], df["name"]).show(10)
# Out:
# +----+--------------------+
# |year|                name|
# +----+--------------------+
# |2009|Australian Grand ...|
# |2009|Malaysian Grand Prix|
# |2009|  Chinese Grand Prix|
# |2009|  Bahrain Grand Prix|
# |2009|  Spanish Grand Prix|
# |2009|   Monaco Grand Prix|
# |2009|  Turkish Grand Prix|
# |2009|  British Grand Prix|
# |2009|   German Grand Prix|
# |2009|Hungarian Grand Prix|
# +----+--------------------+
# only showing top 10 rows

# %%
df.select(df.year.alias('test_col_1'), df.name.alias('test_col_2')).show(10)
# Out:
# +----------+--------------------+
# |test_col_1|          test_col_2|
# +----------+--------------------+
# |      2009|Australian Grand ...|
# |      2009|Malaysian Grand Prix|
# |      2009|  Chinese Grand Prix|
# |      2009|  Bahrain Grand Prix|
# |      2009|  Spanish Grand Prix|
# |      2009|   Monaco Grand Prix|
# |      2009|  Turkish Grand Prix|
# |      2009|  British Grand Prix|
# |      2009|   German Grand Prix|
# |      2009|Hungarian Grand Prix|
# +----------+--------------------+
# only showing top 10 rows

# %%
df.select(col("year").alias('test_col_1'), col("name").alias('test_col_2')).show(10)
# Out:
# +----------+--------------------+
# |test_col_1|          test_col_2|
# +----------+--------------------+
# |      2009|Australian Grand ...|
# |      2009|Malaysian Grand Prix|
# |      2009|  Chinese Grand Prix|
# |      2009|  Bahrain Grand Prix|
# |      2009|  Spanish Grand Prix|
# |      2009|   Monaco Grand Prix|
# |      2009|  Turkish Grand Prix|
# |      2009|  British Grand Prix|
# |      2009|   German Grand Prix|
# |      2009|Hungarian Grand Prix|
# +----------+--------------------+
# only showing top 10 rows

# %%
df.select(df["year"].alias('test_col_1'), df["name"].alias('test_col_2')).show(10)
# Out:
# +----------+--------------------+
# |test_col_1|          test_col_2|
# +----------+--------------------+
# |      2009|Australian Grand ...|
# |      2009|Malaysian Grand Prix|
# |      2009|  Chinese Grand Prix|
# |      2009|  Bahrain Grand Prix|
# |      2009|  Spanish Grand Prix|
# |      2009|   Monaco Grand Prix|
# |      2009|  Turkish Grand Prix|
# |      2009|  British Grand Prix|
# |      2009|   German Grand Prix|
# |      2009|Hungarian Grand Prix|
# +----------+--------------------+
# only showing top 10 rows

# %%
df. drop("url","fp1_date").show(10)
# Out:
# +------+----+-----+---------+--------------------+----------+--------+--------+--------+--------+--------+--------+----------+----------+-----------+-----------+
# |raceId|year|round|circuitId|                name|      date|    time|fp1_time|fp2_date|fp2_time|fp3_date|fp3_time|quali_date|quali_time|sprint_date|sprint_time|
# +------+----+-----+---------+--------------------+----------+--------+--------+--------+--------+--------+--------+----------+----------+-----------+-----------+
# |     1|2009|    1|        1|Australian Grand ...|2009-03-29|06:00:00|      \N|      \N|      \N|      \N|      \N|        \N|        \N|         \N|         \N|
# |     2|2009|    2|        2|Malaysian Grand Prix|2009-04-05|09:00:00|      \N|      \N|      \N|      \N|      \N|        \N|        \N|         \N|         \N|
# |     3|2009|    3|       17|  Chinese Grand Prix|2009-04-19|07:00:00|      \N|      \N|      \N|      \N|      \N|        \N|        \N|         \N|         \N|
# ...

# %%
df.drop("url","fp1_time","fp2_date","fp2_time").show(10)
# Out:
# +------+----+-----+---------+--------------------+----------+--------+--------+--------+--------+----------+----------+-----------+-----------+
# |raceId|year|round|circuitId|                name|      date|    time|fp1_date|fp3_date|fp3_time|quali_date|quali_time|sprint_date|sprint_time|
# +------+----+-----+---------+--------------------+----------+--------+--------+--------+--------+----------+----------+-----------+-----------+
# |     1|2009|    1|        1|Australian Grand ...|2009-03-29|06:00:00|      \N|      \N|      \N|        \N|        \N|         \N|         \N|
# |     2|2009|    2|        2|Malaysian Grand Prix|2009-04-05|09:00:00|      \N|      \N|      \N|        \N|        \N|         \N|         \N|
# |     3|2009|    3|       17|  Chinese Grand Prix|2009-04-19|07:00:00|      \N|      \N|      \N|        \N|        \N|         \N|         \N|
# ...

# %%
df.show(10)
# Out:
# +------+----+-----+---------+--------------------+----------+--------+--------------------+--------+--------+--------+--------+--------+--------+----------+----------+-----------+-----------+
# |raceId|year|round|circuitId|                name|      date|    time|                 url|fp1_date|fp1_time|fp2_date|fp2_time|fp3_date|fp3_time|quali_date|quali_time|sprint_date|sprint_time|
# +------+----+-----+---------+--------------------+----------+--------+--------------------+--------+--------+--------+--------+--------+--------+----------+----------+-----------+-----------+
# |     1|2009|    1|        1|Australian Grand ...|2009-03-29|06:00:00|http://en.wikiped...|      \N|      \N|      \N|      \N|      \N|      \N|        \N|        \N|         \N|         \N|
# |     2|2009|    2|        2|Malaysian Grand Prix|2009-04-05|09:00:00|http://en.wikiped...|      \N|      \N|      \N|      \N|      \N|      \N|        \N|        \N|         \N|         \N|
# ...

# %%
df.withColumnRenamed("raceId","race_id").show(10)
# Out:
# +-------+----+-----+---------+--------------------+----------+--------+--------------------+--------+--------+--------+--------+--------+--------+----------+----------+-----------+-----------+
# |race_id|year|round|circuitId|                name|      date|    time|                 url|fp1_date|fp1_time|fp2_date|fp2_time|fp3_date|fp3_time|quali_date|quali_time|sprint_date|sprint_time|
# +-------+----+-----+---------+--------------------+----------+--------+--------------------+--------+--------+--------+--------+--------+--------+----------+----------+-----------+-----------+
# |      1|2009|    1|        1|Australian Grand ...|2009-03-29|06:00:00|http://en.wikiped...|      \N|      \N|      \N|      \N|      \N|      \N|        \N|        \N|         \N|         \N|
# |      2|2009|    2|        2|Malaysian Grand Prix|2009-04-05|09:00:00|http://en.wikiped...|      \N|      \N|      \N|      \N|      \N|      \N|        \N|        \N|         \N|         \N|
# ...

# %%
df.withColumnRenamed("circuitId", "circuit_id").withColumnRenamed("date","race_date").show(10)
# Out:
# +------+----+-----+----------+--------------------+----------+--------+--------------------+--------+--------+--------+--------+--------+--------+----------+----------+-----------+-----------+
# |raceId|year|round|circuit_id|                name| race_date|    time|                 url|fp1_date|fp1_time|fp2_date|fp2_time|fp3_date|fp3_time|quali_date|quali_time|sprint_date|sprint_time|
# +------+----+-----+----------+--------------------+----------+--------+--------------------+--------+--------+--------+--------+--------+--------+----------+----------+-----------+-----------+
# |     1|2009|    1|         1|Australian Grand ...|2009-03-29|06:00:00|http://en.wikiped...|      \N|      \N|      \N|      \N|      \N|      \N|        \N|        \N|         \N|         \N|
# |     2|2009|    2|         2|Malaysian Grand Prix|2009-04-05|09:00:00|http://en.wikiped...|      \N|      \N|      \N|      \N|      \N|      \N|        \N|        \N|         \N|         \N|
# ...

# %%
df.show(10)
# Out:
# +------+----+-----+---------+--------------------+----------+--------+--------------------+--------+--------+--------+--------+--------+--------+----------+----------+-----------+-----------+
# |raceId|year|round|circuitId|                name|      date|    time|                 url|fp1_date|fp1_time|fp2_date|fp2_time|fp3_date|fp3_time|quali_date|quali_time|sprint_date|sprint_time|
# +------+----+-----+---------+--------------------+----------+--------+--------------------+--------+--------+--------+--------+--------+--------+----------+----------+-----------+-----------+
# |     1|2009|    1|        1|Australian Grand ...|2009-03-29|06:00:00|http://en.wikiped...|      \N|      \N|      \N|      \N|      \N|      \N|        \N|        \N|         \N|         \N|
# |     2|2009|    2|        2|Malaysian Grand Prix|2009-04-05|09:00:00|http://en.wikiped...|      \N|      \N|      \N|      \N|      \N|      \N|        \N|        \N|         \N|         \N|
# ...

# %%
df = df.withColumnRenamed("circuitId","circuit_id").withColumnRenamed("date","race_date")

# %%
df.show(10)
# Out:
# +------+----+-----+----------+--------------------+----------+--------+--------------------+--------+--------+--------+--------+--------+--------+----------+----------+-----------+-----------+
# |raceId|year|round|circuit_id|                name| race_date|    time|                 url|fp1_date|fp1_time|fp2_date|fp2_time|fp3_date|fp3_time|quali_date|quali_time|sprint_date|sprint_time|
# +------+----+-----+----------+--------------------+----------+--------+--------------------+--------+--------+--------+--------+--------+--------+----------+----------+-----------+-----------+
# |     1|2009|    1|         1|Australian Grand ...|2009-03-29|06:00:00|http://en.wikiped...|      \N|      \N|      \N|      \N|      \N|      \N|        \N|        \N|         \N|         \N|
# |     2|2009|    2|         2|Malaysian Grand Prix|2009-04-05|09:00:00|http://en.wikiped...|      \N|      \N|      \N|      \N|      \N|      \N|        \N|        \N|         \N|         \N|
# ...

# %%
df.printSchema()
# Out:
# root
#  |-- raceId: integer (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- round: integer (nullable = true)
#  |-- circuit_id: integer (nullable = true)
#  |-- name: string (nullable = true)
#  |-- race_date: date (nullable = true)
#  |-- time: string (nullable = true)
#  |-- url: string (nullable = true)
#  |-- fp1_date: string (nullable = true)
#  |-- fp1_time: string (nullable = true)
#  |-- fp2_date: string (nullable = true)
#  |-- fp2_time: string (nullable = true)
#  |-- fp3_date: string (nullable = true)
#  |-- fp3_time: string (nullable = true)
#  |-- quali_date: string (nullable = true)
#  |-- quali_time: string (nullable = true)
#  |-- sprint_date: string (nullable = true)
#  |-- sprint_time: string (nullable = true)

# %%
from pyspark.sql.functions import lit

df = df.withColumn("source", lit("F1_Complete_Dataset"))
df.show(10)
# Out:
# +------+----+-----+----------+--------------------+----------+--------+--------------------+--------+--------+--------+--------+--------+--------+----------+----------+-----------+-----------+-------------------+
# |raceId|year|round|circuit_id|                name| race_date|    time|                 url|fp1_date|fp1_time|fp2_date|fp2_time|fp3_date|fp3_time|quali_date|quali_time|sprint_date|sprint_time|             source|
# +------+----+-----+----------+--------------------+----------+--------+--------------------+--------+--------+--------+--------+--------+--------+----------+----------+-----------+-----------+-------------------+
# |     1|2009|    1|         1|Australian Grand ...|2009-03-29|06:00:00|http://en.wikiped...|      \N|      \N|      \N|      \N|      \N|      \N|        \N|        \N|         \N|         \N|F1_Complete_Dataset|
# ...

# %%
df.withColumn("points", lit(25)).show(10)
# Out:
# +------+----+-----+----------+--------------------+----------+--------+--------------------+--------+--------+--------+--------+--------+--------+----------+----------+-----------+-----------+-------------------+------+
# |raceId|year|round|circuit_id|                name| race_date|    time|                 url|fp1_date|fp1_time|fp2_date|fp2_time|fp3_date|fp3_time|quali_date|quali_time|sprint_date|sprint_time|             source|points|
# +------+----+-----+----------+--------------------+----------+--------+--------------------+--------+--------+--------+--------+--------+--------+----------+----------+-----------+-----------+-------------------+------+
# |     1|2009|    1|         1|Australian Grand ...|2009-03-29|06:00:00|http://en.wikiped...|      \N|      \N|      \N|      \N|      \N|      \N|        \N|        \N|         \N|         \N|F1_Complete_Dataset|    25|
# ...

# %%
from pyspark.sql.functions import col

df.withColumn("double_round", col("round") * 2).show(10)
# Out:
# +------+----+-----+----------+--------------------+----------+--------+--------------------+--------+--------+--------+--------+--------+--------+----------+----------+-----------+-----------+-------------------+------------+
# |raceId|year|round|circuit_id|                name| race_date|    time|                 url|fp1_date|fp1_time|fp2_date|fp2_time|fp3_date|fp3_time|quali_date|quali_time|sprint_date|sprint_time|             source|double_round|
# +------+----+-----+----------+--------------------+----------+--------+--------------------+--------+--------+--------+--------+--------+--------+----------+----------+-----------+-----------+-------------------+------------+
# |     1|2009|    1|         1|Australian Grand ...|2009-03-29|06:00:00|http://en.wikiped...|      \N|      \N|      \N|      \N|      \N|      \N|        \N|        \N|         \N|         \N|F1_Complete_Dataset|           2|
# ...

# %%
df.withColumn("source", lit("F1_Complete_Dataset")).show(10)
# Out:
# +------+----+-----+----------+--------------------+----------+--------+--------------------+--------+--------+--------+--------+--------+--------+----------+----------+-----------+-----------+-------------------+
# |raceId|year|round|circuit_id|                name| race_date|    time|                 url|fp1_date|fp1_time|fp2_date|fp2_time|fp3_date|fp3_time|quali_date|quali_time|sprint_date|sprint_time|             source|
# +------+----+-----+----------+--------------------+----------+--------+--------------------+--------+--------+--------+--------+--------+--------+----------+----------+-----------+-----------+-------------------+
# |     1|2009|    1|         1|Australian Grand ...|2009-03-29|06:00:00|http://en.wikiped...|      \N|      \N|      \N|      \N|      \N|      \N|        \N|        \N|         \N|         \N|F1_Complete_Dataset|
# ...

# %%
df.createOrReplaceTempView("races")
spark.sql("SELECT year, name FROM races").show(10)
# Out:
# +----+--------------------+
# |year|                name|
# +----+--------------------+
# |2009|Australian Grand ...|
# |2009|Malaysian Grand Prix|
# |2009|  Chinese Grand Prix|
# |2009|  Bahrain Grand Prix|
# |2009|  Spanish Grand Prix|
# |2009|   Monaco Grand Prix|
# |2009|  Turkish Grand Prix|
# |2009|  British Grand Prix|
# |2009|   German Grand Prix|
# |2009|Hungarian Grand Prix|
# +----+--------------------+
# only showing top 10 rows

# %%
spark.sql("SELECT year, count(*) FROM races\
            group by year order by 2 desc \
            ").show(10)
# Out:
# +----+--------+
# |year|count(1)|
# +----+--------+
# |2024|      24|
# |2023|      22|
# |2022|      22|
# |2021|      22|
# |2018|      21|
# |2019|      21|
# |2016|      21|
# |2012|      20|
# |2017|      20|
# |2014|      19|
# +----+--------+
# only showing top 10 rows

# %%
df2 = spark.sql("SELECT year, count(*) FROM races \
            group by year order by 2 desc \
            ")

# %%
df2.show(10)
# Out:
# +----+--------+
# |year|count(1)|
# +----+--------+
# |2024|      24|
# |2023|      22|
# |2022|      22|
# |2021|      22|
# |2018|      21|
# |2019|      21|
# |2016|      21|
# |2012|      20|
# |2017|      20|
# |2014|      19|
# +----+--------+
# only showing top 10 rows

# %%
spark.sql("SELECT * FROM races where year = 2015").show(10)
# Out:
# +------+----+-----+----------+--------------------+----------+--------+--------------------+--------+--------+--------+--------+--------+--------+----------+----------+-----------+-----------+-------------------+
# |raceId|year|round|circuit_id|                name| race_date|    time|                 url|fp1_date|fp1_time|fp2_date|fp2_time|fp3_date|fp3_time|quali_date|quali_time|sprint_date|sprint_time|             source|
# +------+----+-----+----------+--------------------+----------+--------+--------------------+--------+--------+--------+--------+--------+--------+----------+----------+-----------+-----------+-------------------+
# |   931|2015|    6|         6|   Monaco Grand Prix|2015-05-24|12:00:00|http://en.wikiped...|      \N|      \N|      \N|      \N|      \N|      \N|        \N|        \N|         \N|         \N|F1_Complete_Dataset|
# ...

# %%
result = spark.sql("SELECT raceId, name FROM races WHERE year = 2020")
result.show(10)
# Out:
# +------+--------------------+
# |raceId|                name|
# +------+--------------------+
# |  1031| Austrian Grand Prix|
# |  1032|  Styrian Grand Prix|
# |  1033|Hungarian Grand Prix|
# |  1034|  British Grand Prix|
# |  1035|70th Anniversary ...|
# |  1036|  Spanish Grand Prix|
# |  1037|  Belgian Grand Prix|
# |  1038|  Italian Grand Prix|
# |  1039|   Tuscan Grand Prix|
# |  1040|  Russian Grand Prix|
# +------+--------------------+
# only showing top 10 rows

# %%
spark.sql("SELECT year, count(*) FROM races group by year order by 2 desc").show(10)
# Out:
# +----+--------+
# |year|count(1)|
# +----+--------+
# |2024|      24|
# |2023|      22|
# |2022|      22|
# |2021|      22|
# |2018|      21|
# |2019|      21|
# |2016|      21|
# |2012|      20|
# |2017|      20|
# |2014|      19|
# +----+--------+
# only showing top 10 rows
